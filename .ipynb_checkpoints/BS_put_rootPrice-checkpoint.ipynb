# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np
from scipy.stats import norm
from scipy.optimize import minimize_scalar  
import math

# %%
N = norm.cdf

# %%
import sympy as sp
import sympy.stats
n = sympy.stats.Normal('n', 0, 1)

# %%
def sp_BS_root_put(x0, y0, S, T, r, sigma):
    
    # x0 is usdc amount at zero time
    TV0 = 2 * sp.sqrt(x0 * y0) * sp.sqrt(S)
    
    z1 = - (r - 0.5*sigma**2)*sp.sqrt(T)/sigma
    first_part = (sp.exp(-r*T) * TV0) * sp.stats.cdf(n)(z1)
    _r = r/2
    _sigma = sigma / 2
    z2 = z1 - _sigma * sp.sqrt(T)
    second_part = (sp.exp(-r*T) * TV0) * (sp.exp(-0.5 * _sigma**2 * T)*sp.exp(_r*T)) * sp.stats.cdf(n)(z2)
    
    return first_part - second_part

def sp_BS_CALL(S, K, T, r, sigma):
    d1 = (sp.log(S/K) + (r + sigma**2/2)*T) / (sigma*sp.sqrt(T))
    d2 = d1 - sigma * sp.sqrt(T)
    return S * sp.stats.cdf(n)(d1) - K * sp.exp(-r*T)* sp.stats.cdf(n)(d2)

# %%
x0, y0, x, y, S, K, T, r, sigma, m, v, lam, Nd1, Nd2 = sp.symbols('x0 y0 x y S K T r sigma m v lambda N(d1) N(d2)')

# %%
# phi = sp.Function('phi')                                                                                                   

# class Phi(sp.Function): 
#     def _eval_derivative(self, x): 
#         return phi(self.args[0]) * self.args[0].diff(x)

# bs = sp_BS_CALL(S, K, T, r, sigma).diff(S)
# sp.simplify(bs)
# # bs.subs(sp.erf, sp.Lambda(x, 2*Phi(x*sqrt(2))-1))

# %%
sp.simplify(sp_BS_root_put(x0, y0, S, T, r, sigma))
# Out:
# sqrt(S)*sqrt(x0*y0)*((1 - erf(sqrt(2)*sqrt(T)*(r - 0.5*sigma**2)/(2*sigma)))*exp(T*(r + 0.25*sigma**2)/2) + (erf(sqrt(2)*sqrt(T)*r/(2*sigma)) - 1)*exp(T*r))*exp(-T*(3*r + 0.25*sigma**2)/2)

# %%
sp.simplify(sp_BS_root_put(x0, y0, S, T, r, sigma).diff(S))
# Out:
# sqrt(x0*y0)*((1 - erf(sqrt(2)*sqrt(T)*(r - 0.5*sigma**2)/(2*sigma)))*exp(T*(r + 0.25*sigma**2)/2) + (erf(sqrt(2)*sqrt(T)*r/(2*sigma)) - 1)*exp(T*r))*exp(-T*(3*r + 0.25*sigma**2)/2)/(2*sqrt(S))

# %%
from scipy.special import erf
erf(1)
# Out:
# 0.8427007929497148

# %%
N(1)
# Out:
# 0.8413447460685429

# %%
# works
def delta_BS_root_put(x0, y0, S, T, r, sigma):
    first_part = (1 - erf(np.sqrt(2*T)*(r-0.5*sigma**2)/(2*sigma)))*np.exp(T*(r+0.25*sigma**2)/2)
    second_part = (erf(np.sqrt(2*T)*(r*0.5/sigma)) - 1)*np.exp(T*r)
    return 0.5*np.sqrt(x0*y0/S)*(first_part + second_part)*np.exp(-T*(3*r+0.25*sigma**2)/2)

# %%
x0 = 100
y0 = 0.5
# it means we put in when price was 1000
# T = 1
r = 0
sigma = 1
# maturity = [t/365 for t in range(0, 365)]
prices = [price for price in range(10, 1000, 20)]

deltas = [delta_BS_root_put(x0,y0,price, 0.1, r, sigma) for price in prices]

# %%
plt.plot(prices, deltas)
plt.title('root option deltas of eth price')
plt.xlabel('eth price')
plt.ylabel('delta')
# Out:
# Text(0, 0.5, 'delta')

# %% [markdown]
# ### (wtf above?!)

# %%
# BS_root_put(500, 0.5 , 1, 1, 1000, 0.5, 0, 1)

# %%
# print(sp_BS_root_put(x0, y0, x, y , S, T, r, sigma).evalf(subs={x0:500, y0:0.5, x:1,y:1, S:1000, T:0.5,r:0,sigma:1}))
# print(new_delta_BS_root_put(_x0,_y0,1,1,_S,_T,_r,_sigma))

# %%
# delta_BS_root_put = sp.simplify(sp_BS_root_put(x0, y0, x, y , S, T, r, sigma).diff(S))
# print(delta_BS_root_put)

# %%
def BS_root_put(x0, y0, S, T, r, sigma):
    
    # x0 is usdc amount
    TV0 = 2 * np.sqrt(x0 * y0) * np.sqrt(S)
    
    z1 = - (r - 0.5*sigma**2)*np.sqrt(T)/sigma
    first_part = (np.exp(-r*T) * TV0) * N(z1)
    _r = r/2
    _sigma = sigma / 2
    z2 = z1 - _sigma * np.sqrt(T)
    second_part = (np.exp(-r*T) * TV0) * (np.exp(-0.5 * _sigma**2 * T)*np.exp(_r*T)) * N(z2)
    
    return first_part - second_part

# %%
params = {x0: 50, y0:50/100, x:1, y:1, S:100, T: 0.5, r:0, sigma:1}
# T = 0.3
# r = 0  
# sigma = 0.9
last_price = []
replicated_payoff = []
true_payoff = []

S = 100
K = 100
T = 0.5
r = 0
sigma = 1


x0 = 50
y0 = x0 / S

# sp_BS_root_put(x0, y0, x, y , S, T, r, sigma)

# delta_BS_root_put.evalf(subs={x0:_x0, y0:_y0, x:1,y:1, S:_S, T:_T,r:_r,sigma:_sigma})

for i in range(len(all_paths[:])):
    asset = 0
    initial_usdc = 0
    usdc = initial_usdc
    prev_asset = 0
    
    for j in range(len(all_paths[i])):
        t = (T / steps) * j
        prev_asset = asset
        asset = (delta_BS_root_put(x0,y0,all_paths[i][j],T-t,r,sigma))
#         print('x0: {}, y0: {}, S[i][j]:{},T-t:{}, asset:{}'.format(x0,y0,all_paths[i][j],T-t, asset))
        usdc = usdc - (asset - prev_asset) * all_paths[i][j] 
#         print(asset, usdc)

    last_price.append(all_paths[i][-1])
    replicated_payoff.append(asset*all_paths[i][-1] + usdc - initial_usdc)
    # max((TV0(S0)) - (TV(S))) - root_put_price
    # max(0, K - S) - put_price
    true_payoff.append(max(0, (2*x0) - (2*np.sqrt(y0*x0))* np.sqrt(all_paths[i][-1])) - BS_root_put(x0, y0, S, T, r, sigma))

# x0 = 500 # 500 usdc
# S0 = 120

# print(sp_BS_root_put(x0, y0, x, y , S, T, r, sigma).evalf(subs=params))
# print(sp.simplify(sp_BS_root_put(x0, y0, x, y , S, T, r, sigma).diff(S)).evalf(subs=params))

# %%
# TODO: BS_root_put(x0, y0, S, T, r, sigma) why y0 and S?? they are mutually derived

# %%
# asset = 0
# initial_usdc = 0
# usdc = 0
# prev_asset = 0

# for i in range(len(all_paths[:])):
#     asset = 0
#     initial_usdc = 200
#     usdc = initial_usdc
#     prev_asset = 0
    
#     for j in range(len(all_paths[i])):
#         t = (T / steps) * j
#         prev_asset = asset
#         asset = delta_BS_put(all_paths[i][j], K, T - t, r, sigma)
#         usdc = usdc - (asset - prev_asset) * all_paths[i][j] 
# #         print(asset, usdc)

#     last_price.append(all_paths[i][-1])
#     replicated_payoff.append(asset*all_paths[i][-1] + usdc - initial_usdc)
    
#     true_payoff.append(max(0, K - all_paths[i][-1]) - BS_PUT(S, K, T, r, sigma))

# %%
more_deltas = [delta_BS_root_put(x0,y0,price, 0.5, r, sigma) for price in last_price]
plt.plot(last_price, more_deltas, 'o')
plt.title('deltas')
# Out:
# Text(0.5, 1.0, 'deltas')

# %%
plt.plot(last_price, true_payoff, 'bo')
plt.xlabel('eth price')
plt.ylabel('option payoff')
plt.xlim(xmax=200)
# Out:
# (-5.1565385264758135, 200.0)

# %%
plt.plot(last_price, replicated_payoff, 'o')
plt.xlabel('eth price')
plt.ylabel('option payoff')
plt.xlim(xmax=200)
# Out:
# (-10.622028532684077, 200.0)

# %%
norm.rvs()
# Out:
# -3.373248320847049

# %%
# geometric bwornian motions

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

steps = 300
num_plots = 100
Range = []
Values = [100]

sigma = 1
T = 0.1

plt.style.use('ggplot')
plt.rcParams['lines.linewidth'] = 0.6

fig, ax = plt.subplots()
fig.set_figwidth(12)
fig.set_figheight(6)

colormap = plt.cm.gist_ncar
plt.gca().set_prop_cycle(plt.cycler('color', plt.cm.jet(np.linspace(0, 1, 1))))


Range = np.arange(steps) 

all_paths = []

for i in range(0, num_plots):

    for i in range (1, steps):
        dx = sigma * Values[-1] * norm.rvs() * np.sqrt(0.5 / steps)
#         if x <= 0.5:
#             x = -1
#         else:
#             x = 1
        y = Values[-1] + dx

        Values.append(y)
    all_paths.append(Values)
    ax.plot(Range, Values)
    Values = [100]

# %%
# print((all_paths)[0])
# plt.plot(Range, all_paths[0])

# %%
def delta_BS_put(S, K, T, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2/2)*T) / (sigma*np.sqrt(T))
    return N(d1) - 1

def delta_BS_call(S, K, T, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2/2)*T) / (sigma*np.sqrt(T))
    return N(d1)

def BS_CALL(S, K, T, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2/2)*T) / (sigma*np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    return S * N(d1) - K * np.exp(-r*T)* N(d2)

def BS_PUT(S, K, T, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2/2)*T) / (sigma*np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    return K * np.exp(-r*T)* N(-d2) - S * N(-d1)

# %%
prices = [x for x in range(100, 1000, 100)]
deltas = [BS_PUT(price, 300, 0.5, 0, 1) for price in prices]
plt.plot(prices, deltas)
plt.title('delta BS put')
plt.xlabel('eth price')
# Out:
# Text(0.5, 0, 'eth price')

# %% [markdown]
# ### This is the process of BS call replication (below):

# %%
# delta_BS_put(100,100,0.5, 0, 1)
last_price = []
replicated_payoff = []
true_payoff = []

S = 100
K = 100
T = 0.5
r = 0
sigma = 1

asset = 0
initial_usdc = 200
usdc = initial_usdc
prev_asset = 0

for i in range(len(all_paths[:])):
    asset = 0
    initial_usdc = 200
    usdc = initial_usdc
    prev_asset = 0
    
    for j in range(len(all_paths[i])):
        t = (T / steps) * j
        prev_asset = asset
        asset = delta_BS_call(all_paths[i][j], K, T - t, r, sigma)
        usdc = usdc - (asset - prev_asset) * all_paths[i][j] 
#         print(asset, usdc)

    last_price.append(all_paths[i][-1])
    replicated_payoff.append(asset*all_paths[i][-1] + usdc - initial_usdc)
    
    true_payoff.append(max(0, all_paths[i][-1] - K) - BS_CALL(S, K, T, r, sigma))

# print(all_paths[1][-1])
# print(asset*all_paths[1][-1]+ usdc)

# %%
# print(last_price)
# print('---')
# print(replicated_payoff)

# %%
plt.plot(last_price, true_payoff, 'bo', )

# %%
plt.plot(last_price, replicated_payoff, 'ro')

# %%
# delta_BS_put(100,100,0.5, 0, 1)
last_price = []
replicated_payoff = []
true_payoff = []

# S = 100
K = 100
T = 0.1
r = 0
sigma = 1
x0 = 50
y0 = x0 / K



for i in range(len(all_paths[:])):
    asset = 0   # not sure if it's correct. Maybe shpuld be here asset = 0
    initial_usdc = 0
    usdc = initial_usdc
    prev_asset = asset
    
    for j in range(len(all_paths[i])):
        t = (T / steps) * j
        prev_asset = asset
        asset = new_way_BS_delta_root_put(x0, K, all_paths[i][j], T-t, r, sigma)
        usdc = usdc - (asset - prev_asset) * all_paths[i][j] 
        print(asset, usdc)

    last_price.append(all_paths[i][-1])
    replicated_payoff.append(asset*all_paths[i][-1] + usdc - initial_usdc)
    
    true_payoff.append(max(0, (2*x0) - (2*np.sqrt(y0*x0))* np.sqrt(all_paths[i][-1]) ) - BS_root_put(x0, y0, K, T, r, sigma))

# print(all_paths[1][-1])
# print(asset*all_paths[1][-1]+ usdc)
# Out:
# -0.24689445012347036 24.689445012347036
# -0.25206950183144416 25.185960653204155
# -0.2520425660190921 25.183375553305435
# -0.24866071882181334 24.84989474900084
# -0.2450701431277618 24.485350125053778
# -0.24199890193121718 24.16554107807917
# -0.24578705194044126 24.54796845093917
# -0.24419494124774935 24.385122888995156
# -0.25036986149721113 24.985991392628584
# -0.2502820171004846 24.977436724857636
# -0.24899281508382684 24.850574619961034
# -0.24962132141418583 24.912115975658725
# -0.24745261413559824 24.69600650750434
# -0.2490812764910891 24.856198953914006
# -0.2459241605841837 24.537619720262203
# -0.2490136567032273 24.84171301616403
# -0.24732938555259232 24.673653817937325
# -0.2447452183992877 24.410305786472314
# -0.24420685456159663 24.35519529581592
# -0.2473307489078661 24.666976837565763
# -0.2460642716365362 24.539260410158853
# -0.24250696849862266 24.169895954290258
# -0.2522660141652902 25.10639798062295
# -0.24823893951663312 24.707276668586413
# -0.25171125388061805 25.04201466708038
# -0.24383990061030544 24.23335218517958
# -0.24453665597464572 24.304531861667762
# -0.2374569883440814 23.53744812264527
# -0.23802106047159804 23.598281212793736
# -0.2357302509445483 23.34637983446134
# -0.23860403075311074 23.654845143234255
# -0.2327908415657168 22.99926278357023
# -0.24092634813735533 23.85589968479139
# -0.25421460633397835 25.11275134470691
# -0.2551777822404375 25.203173124135066
# -0.20784019642171522 17.321098238285117
# -0.2075022421966717 17.272156548941613
# -0.20846589092823617 17.410434073636615
# -0.20407996656071362 16.753685050682257
# -0.20882615452948383 17.432498422720766
# -0.21567257989162775 18.35058880848736
# -0.2109909958616293 17.694575577578817
# -0.21842676098591424 18.666869973183235
# -0.21433926133414571 18.11176608249795
# -0.21760486366115608 18.54207692990617
# -0.21572161566036105 18.28954716706356
# -0.22510682414754832 19.445380403159852
# -0.22611104215585354 19.567968761350702
# -0.22065833467374166 18.86897631008205
# -0.2166103016932146 18.330430096323852
# -0.2228448812496985 19.11417582323126
# -0.21675075075122077 18.304334262649405
# -0.21326861879490974 17.82632420446017
# -0.2262299547721926 19.407686810740124
# -0.23212704592022554 20.091133205102746
# -0.22689816562928283 19.456823982192237
# -0.21850307246033712 18.358574741384924
# -0.21675378501128728 18.126004320364324
# -0.21990043706198092 18.53250325089735
# -0.22268786133831578 18.883666493518554
# -0.22799324545050992 19.521354315858865
# -0.2342299090666197 20.23164981784844
# -0.241857492683333 21.046495783469094
# -0.2503393175085193 21.892310032246915

# %%
print(plt.plot(last_price, true_payoff, 'bo'))
print(plt.plot(last_price, replicated_payoff, 'o'))
plt.title('true payoff VS replicated')
plt.legend('tr')
plt.xlim(xmax=200)
# Out:
# [<matplotlib.lines.Line2D object at 0x7fe39ef6a640>]
# [<matplotlib.lines.Line2D object at 0x7fe39ef6aa30>]
# (-1.4005083484498115, 200.0)

# %%
    
### IT WOOOOORKS
def BS_root_put(x0, S, T, r, sigma):
    
    # x0 is usdc amount
#     TV0 = 2 * np.sqrt(x0 * y0) * np.sqrt(S)
    TV0 = 2 * x0

    
    z1 = - (r - 0.5*sigma**2)*np.sqrt(T)/sigma
    first_part = (np.exp(-r*T) * TV0) * N(z1)
    _r = r/2
    _sigma = sigma / 2
    z2 = z1 - _sigma * np.sqrt(T)
    second_part = (np.exp(-r*T) * TV0) * (np.exp(-0.5 * _sigma**2 * T)*np.exp(_r*T)) * N(z2)
    
    return first_part - second_part
    
    

    
# for comparison
def BS_CALL(S, K, T, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2/2)*T) / (sigma*np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    return S * N(d1) - K * np.exp(-r*T)* N(d2)

def BS_PUT(S, K, T, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2/2)*T) / (sigma*np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    return - S * N(d1) + K * np.exp(-r*T)* N(d2)

# %%
stock_price = [x for x in range(10, 500, 10)]
# S0 = 100
x0=50
y0 = x0 / S0
T = 1
r = 0
sigma = 1
K = 1000
put_price = [new_way_BS_delta_root_put(x0, K, price, T, r, sigma) for price in stock_price]


print(plt.plot(stock_price, put_price, 'ro'))
plt.xlabel('eth price')
plt.ylabel('bs root delta')
# Out:
# [<matplotlib.lines.Line2D object at 0x7fe3b8a725e0>]
# Text(0, 0.5, 'bs root delta')

# %%
# from numpy import sqrt, sin, cos, pi, exp
import numpy as np
from scipy.integrate import quad

def num_BS_root_put_payoff(z, S0, TV0, T, r, sigma):
    return np.exp(-r*T)*(TV0 - (TV0/np.sqrt(S0)) * np.sqrt(S0)*np.exp(0.5 * (r - 0.5*sigma**2)*T + 0.5*sigma*np.sqrt(T)*z)) * norm.pdf(z)

# %%
# fixing
# S - price at time T
def fixed_num_BS_root_put_payoff(z, x0, S, T, r, sigma):
    TV0 = 2*x0
    # price at time t=0 derives as x0/y0
    return np.exp(-r*T)*(TV0 - (TV0 * np.exp(0.5 * (r - 0.5*sigma**2)*T + 0.5*sigma*np.sqrt(T)*z))) * norm.pdf(z)

# %%
# S0 = 1000
# K = 1000
T = 0.5
r = 0  
sigma = 1

x0 = 500 # 500 usdc
S0 = 1000
y0 = x0/S0

# TV0 = 2 * x0
# BS_root_put(500, 0.5 , 1, 1, 1000, 0.5, 0, 1)

z2 = - (r - 0.5*sigma**2)*np.sqrt(T)/sigma
# print(z2)

I = quad(fixed_num_BS_root_put_payoff, -100, z2, args=(x0,y0,T,r,sigma))
print(I)
# num_BS_root_put_payoff(z2, S0, TV0, T, r, sigma)
# Out:
# (168.45666367738062, 8.213596304289771e-10)

# %%
# X = [x for x in range(-15000, 0)]
# Y = [quad(num_BS_root_put_payoff, x, z2, args=(S0,TV0,T,r,sigma)) for x in X]

# %%
norm.pdf(0)
# Out:
# 0.3989422804014327

# %% [markdown]
# ### again...

# %%
x0 = 50
K = 100 # this is the initial price, it's equivalent to strike
TV0 = 2 * x0
sigma = 1
r = 0
T = 0.5

# %%
# S is the price at time t (not T)
def num_new_way_BS_delta_root_put(z, x0, K, S, T, r, sigma):
    return -(2*x0/np.sqrt(K)*(0.5/np.sqrt(S))*np.exp(0.5 * (r - 0.5*sigma**2)*T + 0.5*sigma*np.sqrt(T)*z))*norm.pdf(z)

# %%
def new_way_BS_delta_root_put(x0, K, S, T, r, sigma):
    z1 = - (r - 0.5*sigma**2)*np.sqrt(T)/sigma
    _r = r/2
    _sigma = sigma / 2
    z2 = z1 - _sigma * np.sqrt(T)
#     print(z1)
    return -(np.exp(-r*T) * x0 /np.sqrt(K*S)) * (np.exp(-0.5 * _sigma**2 * T)*np.exp(_r*T)) * N(z2)

# %%
def another_way_BS_delta_root_put(x0, K, S, T, r, sigma):
    TV0 = 2*x0
    z1 = - (r - 0.5*sigma**2)*np.sqrt(T)/sigma
    _r = r/2
    _sigma = sigma / 2
    z2 = z1 - _sigma * np.sqrt(T)
    
    body = (np.exp(-r*T) * x0) * (np.exp(-0.5 * _sigma**2 * T)*np.exp(_r*T)) * N(z2)
    
    return -body/np.sqrt(K*S)

# %%
another_way_BS_delta_root_put(x0, K, K, T, r, sigma)
# Out:
# -0.07828442190112299

# %%
z2 = - (r - 0.5*sigma**2)*np.sqrt(T)/sigma
print(z2)
I = quad(num_new_way_BS_delta_root_put, -100, z2, args=(x0,K,K,T,r,sigma))
I
# Out:
# 0.3535533905932738
# (-0.07828442190112297, 8.036233169291504e-14)

# %%
new_way_BS_delta_root_put(x0, K, K, T, r, sigma)
# Out:
# -0.07828442190112297

# %%
prices = [x for x in range(100, 3000, 100)]
deltas = [quad(num_new_way_BS_delta_root_put, -100, z2, args=(x0,K,S,T,r,sigma))[0] for S in prices]

# %%
plt.plot(prices, deltas, 'ro')
