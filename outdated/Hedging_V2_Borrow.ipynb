# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from numpy import sqrt

# %%
# Hedging in Uniswap v2 using

# %%
Yo = 1000 #usdt price 1 eth - time_price
Xo = 1 #how many tokens in eth

# %%
def calculate_value(time_price, now_price):
    
    L = sqrt(time_price)
    r = sqrt(now_price)
    
    return (2*L*(r))

# %%
params = {'priceUpper': 1500}
priceUpper = params['priceUpper']

eth_prices = [price for price in range(0, priceUpper, 1)]

Value = [calculate_value(1, price) for price in range(0, priceUpper, 1)]
print(Value)
# Out:
# [0.0, 2.0, 2.8284271247461903, 3.4641016151377544, 4.0, 4.47213595499958, 4.898979485566356, 5.291502622129181, 5.656854249492381, 6.0, 6.324555320336759, 6.6332495807108, 6.928203230275509, 7.211102550927978, 7.483314773547883, 7.745966692414834, 8.0, 8.246211251235321, 8.48528137423857, 8.717797887081348, 8.94427190999916, 9.16515138991168, 9.38083151964686, 9.591663046625438, 9.797958971132712, 10.0, 10.198039027185569, 10.392304845413264, 10.583005244258363, 10.770329614269007, 10.954451150103322, 11.135528725660043, 11.313708498984761, 11.489125293076057, 11.661903789690601, 11.832159566199232, 12.0, 12.165525060596439, 12.328828005937952, 12.489995996796797, 12.649110640673518, 12.806248474865697, 12.96148139681572, 13.114877048604, 13.2664991614216, 13.416407864998739, 13.564659966250536, 13.711309200802088, 13.856406460551018, 14.0, 14.142135623730951, 14.2828568570857, 14.422205101855956, 14.560219778561036, 14.696938456699069, 14.832396974191326, 14.966629547095765, 15.0996
# ...

# %%
print(plt.plot(eth_prices, Value))

plt.xlabel('S(t)')
plt.ylabel('Value')

plt.ylim(ymax=1500)
# Out:
# ...
# (-3.8716921365211885, 1500.0)

# %%
def delta(price):
    
    delta = L / sqrt(price) - H
    H = L / sqrt(price) = X0
    
    return H
# Out:
#   File "<ipython-input-40-ab1394e54e26>", line 4
#     H = L / sqrt(price) = X0
#         ^
# SyntaxError: cannot assign to operator

# %%
prices = [price for price in range(0, 1500, 1)]

# %%
def culculate_new_value(prices):
    L = np.sqrt(prices)
    return 2*L(np.sqrt(prices)- sqrt(S)) - delta(S)

# %%
print(plt.plot(eth_prices, Value))

plt.xlabel('S(t)')
plt.ylabel('Value')
# Out:
# ...
# Text(0, 0.5, 'Value')
